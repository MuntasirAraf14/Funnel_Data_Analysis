# %% [markdown]
# <a href="https://colab.research.google.com/github/MuntasirAraf14/Funnel_Data_Analysis/blob/main/Funnel_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Set-up

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# #Corporate Styling

# %%
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

print("Everything is fine")
# Out:
# Everything is fine

# %%
df = pd.read_csv("funnel_analysis_data.csv")
df
# Out:
#         User_ID Session_ID        Event            Timestamp   Device Region  \
# 0      USR00001   SES00001       Browse  2025-10-28 07:33:50  Desktop   West
# 1      USR00001   SES00001  Add to Cart  2025-10-28 07:36:50   Tablet   East
# 2      USR00001   SES00001     Checkout  2025-10-28 07:40:50   Mobile   West
# 3      USR00002   SES00002       Browse  2025-10-19 09:15:10  Desktop   East
# 4      USR00002   SES00002  Add to Cart  2025-10-19 09:18:10   Mobile   West
# ...         ...        ...          ...                  ...      ...    ...
# 21658  USR09999   SES09999       Browse  2025-10-03 17:22:58  Desktop  South
# 21659  USR09999   SES09999  Add to Cart  2025-10-03 17:26:58   Tablet   West
# 21660  USR09999   SES09999     Checkout  2025-10-03 17:29:58   Mobile  North
# 21661  USR09999   SES09999     Purchase  2025-10-03 17:34:58   Mobile   East
# 21662  USR10000   SES10000       Browse  2025-10-15 20:32:43   Mobile  South
#
# ...

# %% [markdown]
# ##Perform Basic STEPS

# %%
print("Top 5data\n")
display(df.head())
# Out:
# Top 5data
#     User_ID Session_ID        Event            Timestamp   Device Region  \
# 0  USR00001   SES00001       Browse  2025-10-28 07:33:50  Desktop   West
# 1  USR00001   SES00001  Add to Cart  2025-10-28 07:36:50   Tablet   East
# 2  USR00001   SES00001     Checkout  2025-10-28 07:40:50   Mobile   West
# 3  USR00002   SES00002       Browse  2025-10-19 09:15:10  Desktop   East
# 4  USR00002   SES00002  Add to Cart  2025-10-19 09:18:10   Mobile   West
#
#         Channel Product_Category  Revenue Bounce_Flag
# 0       Organic             Home      0.0         Yes
# 1  Social Media           Beauty      0.0         Yes
# 2         Email           Beauty      0.0         Yes
# 3         Email      Electronics      0.0          No
# 4  Social Media          Fashion      0.0          No

# %%
df.tail()
# Out:
#         User_ID Session_ID        Event            Timestamp   Device Region  \
# 21658  USR09999   SES09999       Browse  2025-10-03 17:22:58  Desktop  South
# 21659  USR09999   SES09999  Add to Cart  2025-10-03 17:26:58   Tablet   West
# 21660  USR09999   SES09999     Checkout  2025-10-03 17:29:58   Mobile  North
# 21661  USR09999   SES09999     Purchase  2025-10-03 17:34:58   Mobile   East
# 21662  USR10000   SES10000       Browse  2025-10-15 20:32:43   Mobile  South
#
#             Channel Product_Category  Revenue Bounce_Flag
# 21658    Google Ads      Electronics     0.00          No
# 21659  Social Media          Fashion     0.00          No
# 21660         Email          Fashion     0.00          No
# 21661         Email          Fashion   960.65          No
# 21662    Google Ads           Beauty     0.00         Yes

# %%
#Random Data from Dataset
df.sample()
# Out:
#        User_ID Session_ID        Event            Timestamp  Device Region  \
# 4729  USR02201   SES02201  Add to Cart  2025-10-12 04:02:40  Tablet  South
#
#            Channel Product_Category  Revenue Bounce_Flag
# 4729  Social Media           Beauty      0.0         Yes

# %%
print(df.columns)
print(f"\ntotal Number of Columns:-  {df.columns.nunique()}")
# Out:
# Index(['User_ID', 'Session_ID', 'Event', 'Timestamp', 'Device', 'Region',
#        'Channel', 'Product_Category', 'Revenue', 'Bounce_Flag'],
#       dtype='object')
#
# total Number of Columns:-  10

# %%
#type of dataset

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# User_ID              object
# Session_ID           object
# Event                object
# Timestamp            object
# Device               object
# Region               object
# Channel              object
# Product_Category     object
# Revenue             float64
# Bounce_Flag          object
# dtype: object

# %%
#timestamp column must be in date time type

df['Timestamp'] = pd.to_datetime(df['Timestamp'])
print(df.dtypes)
# Out:
# User_ID                     object
# Session_ID                  object
# Event                       object
# Timestamp           datetime64[ns]
# Device                      object
# Region                      object
# Channel                     object
# Product_Category            object
# Revenue                    float64
# Bounce_Flag                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21663 entries, 0 to 21662
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           21663 non-null  object
#  1   Session_ID        21663 non-null  object
#  2   Event             21663 non-null  object
#  3   Timestamp         21663 non-null  datetime64[ns]
#  4   Device            21663 non-null  object
#  5   Region            21663 non-null  object
#  6   Channel           21663 non-null  object
#  7   Product_Category  21663 non-null  object
#  8   Revenue           21663 non-null  float64
#  9   Bounce_Flag       21663 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.7+ MB

# %%
#imp information about dataset's numeric columns

df.describe()
# Out:
#                            Timestamp       Revenue
# count                          21663  21663.000000
# mean   2025-10-16 19:56:22.920740608     54.304841
# min              2025-10-01 19:30:17      0.000000
# 25%              2025-10-09 08:31:38      0.000000
# 50%              2025-10-16 19:47:21      0.000000
# 75%              2025-10-24 08:13:17      0.000000
# max              2025-10-31 19:25:15   1998.510000
# std                              NaN    262.692471

# %%
#important information about all columns

df.describe(include = "object")
# Out:
#          User_ID Session_ID   Event  Device Region     Channel  \
# count      21663      21663   21663   21663  21663       21663
# unique     10000      10000       4       3      4           4
# top     USR09979   SES09979  Browse  Tablet   West  Google Ads
# freq           4          4   10000    7237   5462        5435
#
#        Product_Category Bounce_Flag
# count             21663       21663
# unique                5           2
# top         Electronics         Yes
# freq               4405       17343

# %%
#shape of dataset

df.shape
# Out:
# (21663, 10)

# %%
pd.set_option("display.max_rows", None)

# %%
pd.set_option("display.max_rows", None)

# %%
df

# %% [markdown]
# #Data Preprocessing and Cleaning
